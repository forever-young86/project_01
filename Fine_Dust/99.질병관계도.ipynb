# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
data = 'static/data/비염환자.xlsx'
df = pd.read_excel(data)
df.head()
# Out:
#   국민관심질병_성별입원외래별현황(단위_명, 일, 건, 천원)_201801_201812 Unnamed: 1 Unnamed: 2  \
# 0                                            NaN        NaN        NaN
# 1                                            NaN        NaN       진료년월
# 2                                             항목       성별구분     입원외래구분
# 3                                             비염          계          계
# 4                                             비염          남         소계
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1  2018년 01월        NaN        NaN        NaN        NaN  2018년 02월
# 2        환자수       내원일수       청구건수   요양급여비용총액     보험자부담금        환자수
# 3    2223628    3057150    3053275   48203057   35040837    1573843
# 4    1027147    1411601    1409509   22541174   16359894     730096
#
#   Unnamed: 9  ... Unnamed: 308 Unnamed: 309 Unnamed: 310 Unnamed: 311  \
# 0        NaN  ...          NaN          NaN          NaN          NaN
# 1        NaN  ...    2023년 02월          NaN          NaN          NaN
# 2       내원일수  ...          환자수         내원일수         청구건수     요양급여비용총액
# 3    2112485  ...      1434125      1938702      1938020     38899225
# 4     985702  ...       682193       927909       927623     18565021
#
#   Unnamed: 312 Unnamed: 313 Unnamed: 314 Unnamed: 315 Unnamed: 316  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN    2023년 03월          NaN          NaN          NaN
# 2       보험자부담금          환자수         내원일수         청구건수     요양급여비용총액
# 3     29275007      1865532      2582724      2581794     51362329
# 4     13978221       891974      1243003      1242475     24586665
#
#   Unnamed: 317
# 0          NaN
# 1          NaN
# 2       보험자부담금
# 3     38461584
# 4     18424448
#
# [5 rows x 318 columns]

# %%
df.count()      #열 별로 Nan이 아닌 값의 갯수 세기
# Out:
# 국민관심질병_성별입원외래별현황(단위_명, 일, 건, 천원)_201801_201812    8
# Unnamed: 1                                        8
# Unnamed: 2                                        9
# Unnamed: 3                                        9
# Unnamed: 4                                        8
#                                                  ..
# Unnamed: 313                                      9
# Unnamed: 314                                      8
# Unnamed: 315                                      8
# Unnamed: 316                                      8
# Unnamed: 317                                      8
# Length: 318, dtype: int64

# %%
df.drop([1], axis=0, inplace=True)
df.head(5)
# Out:
#   국민관심질병_성별입원외래별현황(단위_명, 일, 건, 천원)_201801_201812 Unnamed: 1 Unnamed: 2  \
# 2                                             항목       성별구분     입원외래구분
# 3                                             비염          계          계
# 4                                             비염          남         소계
# 5                                             비염          남         입원
# 6                                             비염          남         외래
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 2        환자수       내원일수       청구건수   요양급여비용총액     보험자부담금        환자수
# 3    2223628    3057150    3053275   48203057   35040837    1573843
# 4    1027147    1411601    1409509   22541174   16359894     730096
# 5       1467       3689       1504     551758     455635        863
# 6    1026073    1407912    1408005   21989417   15904259     729537
#
#   Unnamed: 9  ... Unnamed: 308 Unnamed: 309 Unnamed: 310 Unnamed: 311  \
# 2       내원일수  ...          환자수         내원일수         청구건수     요양급여비용총액
# 3    2112485  ...      1434125      1938702      1938020     38899225
# 4     985702  ...       682193       927909       927623     18565021
# 5       1826  ...          606         1031          651       277157
# 6     983876  ...       681795       926878       926972     18287865
#
#   Unnamed: 312 Unnamed: 313 Unnamed: 314 Unnamed: 315 Unnamed: 316  \
# 2       보험자부담금          환자수         내원일수         청구건수     요양급여비용총액
# 3     29275007      1865532      2582724      2581794     51362329
# 4     13978221       891974      1243003      1242475     24586665
# 5       217546          716         1419          771       308020
# 6     13760675       891524      1241584      1241704     24278644
#
#   Unnamed: 317
# 2       보험자부담금
# 3     38461584
# 4     18424448
# 5       243506
# 6     18180942
#
# [5 rows x 318 columns]
